# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import bs4
import requests
import time
import datetime
import pandas as pd

from tqdm.notebook import tqdm
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
def setting_up_webdriver(driver_path, url, secs):
    """
    Create Selenium browser object.
    
    Parameters:
        driver_path: String. Google Chrome webdriver file path. 
        url: String. Mercadona webpage.
        secs: Integer. Wait time (seconds) before running next chunk of code.
        
    Return:
        Selenium browser object.
    """
    
    # Loading webdriver
    browser = webdriver.Chrome(driver_path)
    browser.get(url)
    
    # Accepting cookies
    try:
        time.sleep(secs)
        btn_cookies = browser.find_element_by_css_selector("button.ui-button.ui-button--small.ui-button--primary.ui-button--positive")
        btn_cookies.click()
    except:
        pass
    time.sleep(secs)
    
    # Adding postal code
    pst = browser.find_element_by_name("postalCode")
    btn = browser.find_element_by_css_selector("button.button.button-primary.button-big")
    pst.send_keys("28004")
    btn.click()
    time.sleep(secs)
    
    return browser

# %%
def make_categories_list(root_url, start, end=None):
    """
    Given a root url, add at the right the start and end to query X amount of web pages.
    E.g.: ['nico.com/1', 'nico.com/2', 'nico.com/3', 'nico.com/4', 'nico.com/5']
    
    Parameters:
        root_url: String. Base url.
        start: Integer. First value of the range.
        end: Integer. Last value of the range. Defult None. 
            if end=None, returns a list with a single item.
    
    Return:
        List of urls.
        E.g.: make_categories_list("www.test.com/", 1, 3)
        ['www.test.com/1', 'www.test.com/2', 'www.test.com/3']
    """
    if end == None:
        return [root_url + str(start)]
    else: 
        return [root_url + str(x) for x in range(start, end+1)]

# %%
def get_html(webdriver):
    """
    Given a webdriver object, return its full raw html in a BeautifulSoup object
    
    Parameters:
        webdriver: Selenium webdriver object
        
    Returns:
        BeautifulSoup object
    """
    
    html = webdriver.page_source
    soup = bs4.BeautifulSoup(html)
    return soup

# %%
def parse_product(category, subcategory, prod):
    """
    Parse a Beautiful Soup product button returning the item's features 
    
    Parameters:
        Category: String. Category
        subcategory: String. Subcategory
        prod: Beautiful Soup object to parse
        
    Returns:
        Parsed data in a list. E.g.:
        ['Aceite, vinagre y sal', 'Aceite de oliva', 'Aceite de oliva 0,4º Hacendado', 'Garrafa 5 L','10,60 €', 
        'https://prod-mercadona.imgix.net/images/236a405e60648cf189d4a4b3a3403983.jpg?fit=crop&h=300&w=300']
    """
    
    img_link = prod.img["src"]
    name = prod.h4.text
    specs = prod.find_all("span", attrs={"class": "footnote1-r"})
    specs = "".join([spec.text for spec in specs])
    price = prod.find("div", attrs={"class": "product-price"}).p.text
    
    return [category, subcategory, name, specs, price, img_link]

# %%
def get_category_page(webdriver, link, secs):
    """
    Check for not found pages.
    
    Parameters:
        webdriver: Selenium object. 
        link: String. Link to check, Not found links return a generic not found page. 
        secs: Integer. Wait time in seconds between iteration.
        
    Return:
        Selenium object pointing to a new web page.
    """
    
    webdriver.get(link)
    time.sleep(secs)
    
    # Checks for not found pages. Not found return None. 
    if link[-3:] == webdriver.current_url[-3:]:
        return webdriver
    else:
        return None

# %%
def get_raw_data(soup):
    """
    Return a list of lists. Each element represents one item of the current page.
    
    Parameters:
        soup: BeautifulSoup object. Current raw HTML to parse.
        
    Return:
        List of lists. Each element of the list comes fromm the parse_product function. 
        E.g.: [['Lechuga y ensalada preparada', 'Lechuga', 'Lechuga iceberg', 'Pieza 1 ud.', '0,79 €', 
        'https://prod-mercadona.imgix.net/images/e047afab489d1c6a9ffc9e7da122ce3f.jpg?fit=crop&h=300&w=300'],
        ...]
        
    Notes:
        March 15th
        - h3 category-detail__name div was changed to h1
        - h3 section class section was changed to h2 but only on category-section class pages. 
    """
    
    # Fetch main category.
    category = soup.find("div", attrs={"class": "category-detail__content"}).h1.text
    
    # Fetch subcategories.
    try:
        sections = soup.find_all("section", attrs={"class": "section"})
        sections[0].h2.text # testing web page arrangement
        
    # Some pages have a diffent arrangement, like https://tienda.mercadona.es/categories/31
    except AttributeError as error01: 
        sections = soup.find_all("div", attrs={"class": "category-section"})
    
    # Fetch every product and its features.
    results = []
    for section in sections:
        
        try:
            name = section.h3.text
        # Pages like categories/31 have a different arragenment.
        except AttributeError as error02:
            name = section.h2.text
            
        products = section.find_all("button", attrs={"class": "product-cell__content-link"})
        section_results = [parse_product(category=category, subcategory=name, prod=product) for product in products]
        results.extend(section_results)
    
    return results

# %%
def products2pandas(products_list):
    """
    Given a product list, create a dataframe which columns are:
    "Category", "Subcategory", "Product", "Specs", "Price", "img_link"
    
    Parameters:
        products_list: List. List coming from get_raw_data function.
        
    Return:
        Pandas data frame containing all parsed data. 
    """
    
    cols = ["Category", "Subcategory", "Product", "Specs", "Price", "img_link"]
    df = pd.DataFrame(data=products_list, columns=cols)
    return df

# %%
def save_df(df, path):
    """
    Given a path, save products dataframe in csv format.
    
    Parameters:
        df: Pandas data frame.
        path: String. Relative or Absolute path where the file should be stored.
        
    Returns:
        None. Saves pandas data frame in csv format.
    """
    df.to_csv(path, index=False)
    print(f"Dataframe saved at {path}")

# %%
def main(start_page, end_page=None):
    """
    Parse Mercadona webpage returning a pandas dataframe with all available products and its features.
    """
    driver = "../bin/chromedriver"
    url = "https://tienda.mercadona.es/"
    categories_url = "https://tienda.mercadona.es/categories/"
    
    # Initializing webdriver
    print("Initializing browser.")
    browser = setting_up_webdriver(driver, url, 3)
    ctgry_list = make_categories_list(categories_url, start_page, end_page)
    
    # Parsing webpage
    print("Fetching and parsing data from webpage.")
    final_results, not_found = [], []
    for link in tqdm(ctgry_list):
        current_page = get_category_page(browser, link, 3)
        if current_page is not None: 
            soup = get_html(current_page)
            results = get_raw_data(soup)
            final_results.extend(results)
        else:
            not_found.append(link)
    
    # Terminating webdriver
    browser.close()
    browser.quit()
    
    # Create a pandas df using the list of products as data
    print("Saving fetched data into a csv file.")
    df = products2pandas(final_results)
    
    # Add run time and supermarket to the data frame
    supermarket = "Mercadona"
    run_time = datetime.datetime.now().strftime("%Y-%m-%d")
    df.insert(loc=0, column="Supermarket", value=supermarket)
    df["Time"] = run_time
    
    # Save data frame as CSV
    save_df(df, f"../data/{supermarket}_{run_time}.csv")
    
    print("Process completed.")
    return df

# %%
df = main(1, 300)
df
# Out:
# Initializing browser.
# Fetching and parsing data from webpage.
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Saving fetched data into a csv file.
# Dataframe saved at ../data/Mercadona_2021-10-24.csv
# Process completed.
#      Supermarket                          Category            Subcategory  \
# 0      Mercadona                             Fruta          Plátano y uva
# 1      Mercadona                             Fruta          Plátano y uva
# 2      Mercadona                             Fruta          Plátano y uva
# 3      Mercadona                             Fruta          Plátano y uva
# 4      Mercadona                             Fruta          Plátano y uva
# ...          ...                               ...                    ...
# 6390   Mercadona  Utensilios de limpieza y calzado  Plantillas y cordones
# 6391   Mercadona  Utensilios de limpieza y calzado  Plantillas y cordones
# 6392   Mercadona  Utensilios de limpieza y calzado  Plantillas y cordones
# 6393   Mercadona  Utensilios de limpieza y calzado  Plantillas y cordones
# 6394   Mercadona  Utensilios de limpieza y calzado  Plantillas y cordones
#
#                                           Product                 Specs  \
# 0                             Plátano de Canarias    Pieza 170 g aprox.
# 1                                          Banana    Pieza 190 g aprox.
# 2                                   Plátano macho    Pieza 290 g aprox.
# 3                         Uva blanca sin semillas  Bandeja 750 g aprox.
# 4                          Uva negra sin semillas  Bandeja 750 g aprox.
# ...                                           ...                   ...
# 6390     Plantillas Lady talla 37-40 Bosque Verde         Paquete 2 ud.
# 6391     Plantillas Piel talla 22-46 Bosque Verde         Paquete 2 ud.
# 6392                Talonera de Piel Bosque Verde         Paquete 2 ud.
# 6393  Plantillas Gel Antideslizantes Bosque Verde         Paquete 2 ud.
# 6394                 Protector Talón Bosque Verde         Paquete 2 ud.
#
#        Price                                           img_link        Time
# 0     0,37 €  https://prod-mercadona.imgix.net/images/686b75...  2021-10-24
# 1     0,20 €  https://prod-mercadona.imgix.net/images/69edef...  2021-10-24
# 2     0,57 €  https://prod-mercadona.imgix.net/images/c22baa...  2021-10-24
# 3     2,77 €  https://prod-mercadona.imgix.net/images/7b5610...  2021-10-24
# 4     2,77 €  https://prod-mercadona.imgix.net/images/03e5b8...  2021-10-24
# ...      ...                                                ...         ...
# 6390  3,20 €  https://prod-mercadona.imgix.net/images/ac9abf...  2021-10-24
# 6391  3,25 €  https://prod-mercadona.imgix.net/images/f6fde1...  2021-10-24
# 6392  2,15 €  https://prod-mercadona.imgix.net/images/c11912...  2021-10-24
# 6393  3,00 €  https://prod-mercadona.imgix.net/images/c20de1...  2021-10-24
# 6394  1,60 €  https://prod-mercadona.imgix.net/images/a25d6b...  2021-10-24
#
# [6395 rows x 8 columns]

# %%
driver = "../bin/chromedriver"
url = "https://tienda.mercadona.es/"
categories_url = "https://tienda.mercadona.es/categories/"

# Initializing webdriver
print("Initializing browser.")
browser = setting_up_webdriver(driver, url, 3)
ctgry_list = make_categories_list(categories_url, 26, 27)

# Parsing webpage
print("Fetching and parsing data from webpage.")
final_results, not_found = [], []
for link in tqdm(ctgry_list):
    current_page = get_category_page(browser, link, 3)
    if current_page is not None: 
        soup = get_html(current_page)
        results = get_raw_data(soup)
        final_results.extend(results)
    else:
        not_found.append(link)
# Out:
# Initializing browser.
# Fetching and parsing data from webpage.
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))

# %%
final_results
# Out:
# [['Fruta',
#   'Plátano y uva',
#   'Plátano de Canarias',
#   'Pieza 170 g aprox.',
#   '0,37 €',
#   'https://prod-mercadona.imgix.net/images/686b751a3e806d7775c5675942b8a2f4.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Plátano y uva',
#   'Banana',
#   'Pieza 190 g aprox.',
#   '0,20 €',
#   'https://prod-mercadona.imgix.net/images/69edef3541bbf3f4b7173c9d617a5698.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Plátano y uva',
#   'Plátano macho',
#   'Pieza 290 g aprox.',
#   '0,57 €',
#   'https://prod-mercadona.imgix.net/images/c22baa2a17de06fbf8477ef25392b7ca.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Plátano y uva',
#   'Uva blanca sin semillas',
#   'Bandeja 750 g aprox.',
#   '2,77 €',
#   'https://prod-mercadona.imgix.net/images/7b5610514b8fc646d0a02def291b8b6d.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Plátano y uva',
#   'Uva negra sin semillas',
#   'Bandeja 750 g aprox.',
#   '2,77 €',
#   'https://prod-mercadona.imgix.net/images/03e5b8dfe12603855c5c3e1cfbfebc28.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Plátano y uva',
#   'Uva negra con semillas',
#   'Granel 500 g aprox.',
#   '1,00 €',
#   'https://prod-mercadona.imgix.net/images/822434f6abf43674d54882a43a28fd0c.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Plátano y uva',
#   'Uva roja sin semillas',
#   'Bandeja 750 g aprox.',
#   '2,77 €',
#   'https://prod-mercadona.imgix.net/images/527c0a13ecf06d5097438cd2e8a9ef07.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Manzana golden',
#   'Pieza 230 g aprox.',
#   '0,39 €',
#   'https://prod-mercadona.imgix.net/images/53687de52a3b197dc1d7c3417d693ef8.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Manzanas golden',
#   'Bolsa 1,5 kg aprox.',
#   '2,00 €',
#   'https://prod-mercadona.imgix.net/images/59658e20cce6ca40e294edbe32d8b609.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Pera conferencia',
#   'Pieza 190 g aprox.',
#   '0,34 €',
#   'https://prod-mercadona.imgix.net/images/ee3e71e5011511764af6ba3edc41f4d2.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Peras conferencia',
#   '1,5 kg aprox.',
#   '2,09 €',
#   'https://prod-mercadona.imgix.net/images/51032a014399414f057b3020a930bf6b.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Manzana fuji',
#   'Pieza 160 g aprox.',
#   '0,35 €',
#   'https://prod-mercadona.imgix.net/images/52a4d34c92d6aeeb8c9a8892a3c8f769.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Manzana royal gala',
#   'Pieza 190 g aprox.',
#   '0,32 €',
#   'https://prod-mercadona.imgix.net/images/966d3b08efd621e942126a54e6b81ed4.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Manzanas royal gala',
#   'Bolsa 1,5 kg aprox.',
#   '2,09 €',
#   'https://prod-mercadona.imgix.net/images/72af5bfc30fcadef171074b4e1a0f420.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Pera ercolina',
#   'Bandeja 500 g aprox.',
#   '1,20 €',
#   'https://prod-mercadona.imgix.net/images/f42adc4fbd03916a504215344fc26ead.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Manzana granny smith',
#   'Pieza 210 g aprox.',
#   '0,35 €',
#   'https://prod-mercadona.imgix.net/images/06e8c47d7373ac738378135cc9787b6b.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Pera blanquilla',
#   'Pieza 120 g aprox.',
#   '0,23 €',
#   'https://prod-mercadona.imgix.net/images/b23fd8ecc2d3e24f0740d1016b37e712.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Manzana y pera',
#   'Manzana reineta',
#   'Pieza 210 g aprox.',
#   '0,48 €',
#   'https://prod-mercadona.imgix.net/images/1cceaf65ea6b724bb4c47bb9432bfd90.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Melón y sandía',
#   'Medio melón piel de sapo',
#   '1/2 Pieza 1,57 kg aprox.',
#   '2,87 €',
#   'https://prod-mercadona.imgix.net/images/2d034c1b80642d033f7b5aecd3fb8269.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Melón y sandía',
#   'Melón piel de sapo',
#   'Pieza 2,7 kg aprox.',
#   '4,29 €',
#   'https://prod-mercadona.imgix.net/images/bd4459355f58bc265a2c6720b688e3c3.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Limones',
#   'Malla 1 kg',
#   '2,09 €',
#   'https://prod-mercadona.imgix.net/images/b53807ade14ad4f2fe4b654c19e53025.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Limón',
#   'Pieza 180 g aprox.',
#   '0,41 €',
#   'https://prod-mercadona.imgix.net/images/c5c512407bc265ae901a3b8efc24ac23.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Mandarina',
#   'Pieza 100 g aprox.',
#   '0,24 €',
#   'https://prod-mercadona.imgix.net/images/f7c744eeadc68f28645c55dac23a136c.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Mandarina',
#   'Malla 1 kg',
#   '1,99 €',
#   'https://prod-mercadona.imgix.net/images/6b3a1e5b41c5cdc7145cee9445c5f6d6.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Mandarinas',
#   '1,4 kg',
#   '3,35 €',
#   'https://prod-mercadona.imgix.net/images/95edb6c60f13f4f6c82648ebb2aaeaff.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Naranja para mesa',
#   'Pieza 300 g aprox.',
#   '0,60 €',
#   'https://prod-mercadona.imgix.net/images/0e0431fbcd08dac4b7df7dd034760193.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Naranjas para zumo',
#   'Malla 3 kg',
#   '5,37 €',
#   'https://prod-mercadona.imgix.net/images/83becaf029aeea3fac731b94ccb66afe.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Naranjas para zumo',
#   'Malla 5 kg',
#   '7,45 €',
#   'https://prod-mercadona.imgix.net/images/e359d053df06b79de0b89951b90f90ef.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Pomelo',
#   'Pieza 370 g aprox.',
#   '0,83 €',
#   'https://prod-mercadona.imgix.net/images/df502e5ff7cbbc260bfb2a4ae2a2a583.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Cítricos',
#   'Limas',
#   '400 g aprox.',
#   '1,40 €',
#   'https://prod-mercadona.imgix.net/images/f723d90ac57dee030d02555d6a3441e6.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Kiwis amarillos',
#   '500 g aprox.',
#   '3,00 €',
#   'https://prod-mercadona.imgix.net/images/4752277b3e81b791947b5630a02ac815.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Kiwi verde',
#   'Pieza 100 g aprox.',
#   '0,39 €',
#   'https://prod-mercadona.imgix.net/images/32214f2eedbb801a0275c14de2fc7ff6.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Kiwis verdes',
#   '1 kg aprox.',
#   '3,69 €',
#   'https://prod-mercadona.imgix.net/images/9c08be85d7f7fc1375935f5a09fb896d.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Aguacate',
#   'Pieza 240 g aprox.',
#   '1,03 €',
#   'https://prod-mercadona.imgix.net/images/5bdb23b103ea75a34562a3bdf877024b.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Aguacates',
#   '550 g aprox.',
#   '2,25 €',
#   'https://prod-mercadona.imgix.net/images/9bfdcd21a52b3d924e3ac16ea8baf918.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Piña',
#   'Pieza 1,74 kg aprox.',
#   '1,72 €',
#   'https://prod-mercadona.imgix.net/images/c09ba6e9981ee0651de3864276e8ed9f.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Media piña',
#   '1/2 Pieza 1,02 kg aprox.',
#   '1,21 €',
#   'https://prod-mercadona.imgix.net/images/54338cf8b271d3aa717ad5e4f65fbe3f.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Guacamole Hacendado',
#   'Tarrina 500 g',
#   '3,29 €',
#   'https://prod-mercadona.imgix.net/images/5c3a7d00a6c79339f48bae00593089ed.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Guacamole Hacendado',
#   'Tarrina 200 g',
#   '1,59 €',
#   'https://prod-mercadona.imgix.net/images/534186c0a94952f5b363f467580cf747.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Mango',
#   'Pieza 610 g aprox.',
#   '1,43 €',
#   'https://prod-mercadona.imgix.net/images/c80c68c2129b94e788b8e03270c8bfdb.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Piña natural a rodajas',
#   'Bote 500 g aprox.',
#   '2,55 €',
#   'https://prod-mercadona.imgix.net/images/447329070430fee9d487dd3124975cb8.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Papaya',
#   'Pieza 1,42 kg aprox.',
#   '6,38 €',
#   'https://prod-mercadona.imgix.net/images/3ceab3996e1d715362ddee63bf01f39a.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Media papaya',
#   '1/2 Pieza 660 g aprox.',
#   '3,10 €',
#   'https://prod-mercadona.imgix.net/images/c16438e867d10b4b34bc50f292fc5bb6.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Coco troceado',
#   'Bandeja 120 g',
#   '1,69 €',
#   'https://prod-mercadona.imgix.net/images/5792354cbdafdea5069c83376efd0bb7.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Fruta tropical',
#   'Chirimoya',
#   'Pieza 460 g aprox.',
#   '0,92 €',
#   'https://prod-mercadona.imgix.net/images/bef1e56ee501ae79a4c2a6a8f05b977b.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Fresas',
#   'Bandeja 400 g aprox.',
#   '2,32 €',
#   'https://prod-mercadona.imgix.net/images/9d76901a0efd72d6b5f9d7a98ce0cea2.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Frambuesas',
#   'Bandeja 170 g',
#   '1,99 €',
#   'https://prod-mercadona.imgix.net/images/8627323a35a042eab5067161afbf7461.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Ciruela amarilla',
#   'Pieza 120 g aprox.',
#   '0,33 €',
#   'https://prod-mercadona.imgix.net/images/a1644a9b9408270f7844c6cbf0516834.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Moras',
#   'Bandeja 125 g',
#   '2,25 €',
#   'https://prod-mercadona.imgix.net/images/db3cd3fb258ed66a4773e4a103ed4d6f.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Arándanos',
#   'Vaso 225 g',
#   '2,69 €',
#   'https://prod-mercadona.imgix.net/images/a367ac3b20f085088d1750cb83edb8f5.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Melocotón amarillo',
#   'Pieza 340 g aprox.',
#   '1,02 €',
#   'https://prod-mercadona.imgix.net/images/a95baa89b1256c1ac74fa4dfe23d36cc.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Ciruelas amarilla mini',
#   '590 g aprox.',
#   '1,47 €',
#   'https://prod-mercadona.imgix.net/images/dffce37cca57264fd1b92bde8d1f1a4b.jpg?fit=crop&h=300&w=300'],
#  ['Fruta',
#   'Otras frutas',
#   'Granada',
#   'Pieza 300 g aprox.',
#   '0,60 €',
#   'https://prod-mercadona.imgix.net/images/7d694daab3f806cbd96bc70a22976c69.jpg?fit=crop&h=300&w=300']]
